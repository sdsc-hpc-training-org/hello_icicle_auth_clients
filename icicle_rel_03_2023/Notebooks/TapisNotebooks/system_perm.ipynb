# %%
import time
import pprint as pp
import datetime
from getpass import getpass
import pytz
import neo4jupyter
from py2neo import Graph
from tapipy.tapis import Tapis

# %%
start = time.time()

# Base URL for Tapis
base_url = "https://icicle.tapis.io"
username = str(input("username"))

# Get Tapis object if it isn't already created.
try:
    if t.base_url == base_url and t.username == username and t.access_token:
        print("Tapis object already exists.")
        if t.access_token.expires_at < datetime.datetime.now(pytz.utc):
            print("Existing Tapis token expired, getting new token.")
            raise
    else:
        print("Creating new Tapis object.")
        raise
except:
    try:
        t = Tapis(base_url = base_url,
                  username = username,
                  password = getpass('password'))
        t.get_tokens()
    except Exception as e:
        print(f"\nBROKEN! timeout: {time.time() - start}\n")
        raise

# V3 Headers
header_dat = {"X-Tapis-token": t.access_token.access_token,
              "Content-Type": "application/json"}

# Service URL
url = f"{base_url}/v3"                   # remote

print(time.time() - start)
print(f"base_url: {base_url}")
print(f"serv_url: {url}")
# Out:
# Creating new Tapis object.
# 6.037235975265503
# base_url: https://icicle.tapis.io
# serv_url: https://icicle.tapis.io/v3

# %%
t.systems.getSystems()
# Out:
# [
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: mkyzubr
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: anothersystemtest
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: mkyzubr.testing4
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: mkyzubr.testing3
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: VERYGOODSYSTEM
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PASSWORD
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: VERYGOODSYSTEM3
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: VERYGOODSYSTEM2
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: test3
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PASSWORD
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: stampede2.mkyzubr4
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PASSWORD
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: stampede2.mkyzubr5
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: TOKEN
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: stampede2.mkyzubr3
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: stampede2.mkyzubr2
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX]

# %%
t.systems.grantUserPerms(systemId='mkyzubr.testing4', userName='ad1616', permissions=['MODIFY', 'EXECUTE'])
# Out:
# {'result': None,
#  'status': 'success',
#  'message': 'SYSAPI_PERMS_GRANTED Permissions granted for system. jwtTenant: icicle jwtUser: mkyzubr OboTenant: icicle OboUser: mkyzubr System: mkyzubr.testing4 User: ad1616 Permissions: EXECUTE,MODIFY,READ',
#  'version': '1.3.3',
#  'commit': '8c66599c',
#  'build': '2023-06-01T13:10:24Z',
#  'metadata': None}

# %%
t.systems.shareSystemPublic(systemId='mkyzubr.testing4')
# Out:
# url: http://icicle.tapis.io/v3/systems/share_public/mkyzubr.testing4

# %%
t.systems.getSystems(listType='ALL')
# Out:
# [
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: mkyzubr
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: anothersystemtest
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: mkyzubr.testing4
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: mkyzubr.testing3
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: VERYGOODSYSTEM
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PASSWORD
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: VERYGOODSYSTEM3
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: VERYGOODSYSTEM2
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: test3
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PASSWORD
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: stampede2.mkyzubr4
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PASSWORD
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: stampede2.mkyzubr5
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: TOKEN
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: stampede2.mkyzubr3
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX,
#
#  canExec: true
#  defaultAuthnMethod: PKI_KEYS
#  effectiveUserId: mkyzubr
#  host: stampede2.tacc.utexas.edu
#  id: stampede2.mkyzubr2
#  owner: mkyzubr
#  parentId: None
#  systemType: LINUX]
